# %% [markdown]
# # Apple store locations in the US

# %%
import json
import requests
import pandas as pd
import jupyter_black
import altair as alt
import datetime as dt
import geopandas as gpd
from vega_datasets import data

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %%
today = dt.date.today().strftime("%Y-%m-%d")

# %%
place = 'apple store'
place_formal = 'Apple Store'

# %% [markdown]
# ---

# %% [markdown]
# ## Grab store list from Apple

# %% [markdown]
# #### Request the store locator json

# %%
params = {
    "locale": "en_US",
}

response = requests.get("https://www.apple.com/rsp-web/store-search", params=params)

# %% [markdown]
# #### Put it into a dataframe

# %%
src = pd.DataFrame(response.json()['results']).reset_index(drop=True)

# %% [markdown]
# #### Unpack nested columns

# %%
src[['address1', 'address2', 'city', 'stateCode', 'stateName', 'postal']] = pd.json_normalize(src['address'])

# %%
src[['latitude', 'longitude']] = pd.json_normalize(src['geolocation'])

# %% [markdown]
# #### Clean up into a dataframe with just columns we need

# %%
df = src.drop(['locale', 'geolocation', 'address', 'address2', 'storeSlug', 'cardImage', 'storeHours'], axis=1).rename(columns={'address1':'address', 'stateName':'state', 'stateCode':'state_abbr'}).copy()

# %% [markdown]
# #### How many are there in US?

# %%
len(df)
# Out:
# 273

# %%
df.head()
# Out:
#   storeNumber         storeName       telephone                      email  \
# 0        R266     Bridge Street  (256) 327-8800     bridgestreet@apple.com
# 1        R796  Birkdale Village  (704) 972-0980  birkdalevillage@apple.com
# 2        R131        La Cantera  (210) 276-2302        lacantera@apple.com
# 3        R550      Valley Plaza  (661) 396-3480      valleyplaza@apple.com
# 4        R053          Millenia  (407) 352-5551         millenia@apple.com
#
#                     address          city state_abbr           state postal  \
# 0     320 The Bridge Street    Huntsville         AL         Alabama  35806
# 1           8805 Townley Rd  Huntersville         NC  North Carolina  28078
# 2  15900 La Cantera Parkway   San Antonio         TX           Texas  78256
# 3          2701 Ming Avenue   Bakersfield         CA      California  93304
# 4          4200 Conroy Road       Orlando         FL         Florida  32839
#
#     latitude   longitude
# 0  34.716144  -86.673021
# 1  35.444770  -80.878600
# 2  29.593330  -98.615560
# 3  35.337950 -119.032710
# 4  28.486000  -81.431740

# %% [markdown]
# ---

# %% [markdown]
# ## Geography

# %% [markdown]
# #### Make it a geodataframe

# %%
df_geo = df.copy()

# %%
gdf = gpd.GeoDataFrame(
    df_geo, geometry=gpd.points_from_xy(df_geo.longitude, df_geo.latitude)
)

# %%
locations_gdf = gdf.set_crs("EPSG:4326").copy()

# %% [markdown]
# ---

# %% [markdown]
# ## Maps

# %% [markdown]
# #### US states background

# %%
background = (
    alt.Chart(alt.topo_feature(data.us_10m.url, feature="states"))
    .mark_geoshape(fill="#e9e9e9", stroke="white")
    .properties(width=800, height=500, title=f"{place_formal} locations")
    .project("albersUsa")
)

# %% [markdown]
# #### Location points map

# %%
points = (
    alt.Chart(gdf)
    .mark_circle(size=10, color="#0088cc")
    .encode(
        longitude="longitude:Q",
        latitude="latitude:Q",
    )
)

point_map = background + points
point_map.configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Location proportional symbols map

# %%
symbols = (
    alt.Chart(gdf)
    .transform_aggregate(
        latitude="mean(latitude)",
        longitude="mean(longitude)",
        count="count()",
        groupby=["state"],
    )
    .mark_circle()
    .encode(
        longitude="longitude:Q",
        latitude="latitude:Q",
        size=alt.Size("count:Q", title="Count by state"),
        color=alt.value("#0088cc"),
        tooltip=["state:N", "count:Q"],
    )
    .properties(title=f"Number of {place_formal} in US, by average lon/lat of locations")
)

symbol_map = background + symbols
symbol_map.configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Exports

# %% [markdown]
# #### JSON

# %%
df.to_json(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.json",
    indent=4,
    orient="records",
)

# %% [markdown]
# #### CSV

# %%
df.to_csv(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.csv", index=False
)

# %% [markdown]
# #### GeoJSON

# %%
locations_gdf.to_file(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.geojson",
    driver="GeoJSON",
)
